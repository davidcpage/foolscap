# %% [markdown]
# # Demo notebook
#
# A tiny `.ipynb` for trying the **read-only Jupyter card**. Drag it onto the canvas (or double-click it in a directory card) and it opens as an `ipynb` card. Markdown renders as prose, code is syntax-highlighted, and outputs render below each cell.
#
# - markdown cells → prose
# - code cells → highlighted source + saved outputs
# - html/image outputs → rendered faithfully

# %%
import math
print("hello from a code cell")
6 * 7
# Out:
# hello from a code cell
# 42

# %%
df  # renders its text/html representation raw
# Out:
#    x  y
# 0  1  2
# 1  3  4

# %%
1 / 0  # an error output renders with ANSI stripped
# Out:
# ZeroDivisionError: division by zero
